# %%
import pdfplumber

# %%
pdf = pdfplumber.open("texte_1.pdf")
first_page = pdf.pages[0]
im = first_page.to_image()
text = first_page.extract_text(keep_blank_chars=True)

# %%
im

# %%
text
# Out:
# ''

# %% [markdown]
# ---

# %%
import PyPDF2

# %% [markdown]
# #### 1ere version

# %%
reader = PyPDF2.PdfReader("texte_1.pdf")
page = reader.pages[0]
page.extract_text()
# Out:
# ''

# %% [markdown]
# #### 2e version

# %%
pdf_file = open('texte_1.pdf', 'rb')
pdf_reader = PyPDF2.PdfReader(pdf_file)

page = pdf_reader.pages[0]
texte = page.extract_text()
texte

#pdf_file.close()
# Out:
# ''

# %% [markdown]
# #### 3e version

# %%
pdf_file = open('texte_1.pdf', 'rb')
pdf_reader = PyPDF2.PdfReader(pdf_file)
text = ''
for page in range(len(pdf_reader.pages)) :
    text += pdf_reader.pages[page].extract_text()
texte
# Out:
# ''

# %% [markdown]
# ---

# %%
import pdfquery

# %%
def extract_data_from_pdf(file_path) :
    pdf = pdfquery.PDFQuery(file_path)
    pdf.load()
    label = pdf.pq('LTTextLineHorizontal:contains("Canton")')
    return label
extract_data_from_pdf('texte_1.pdf')
# Out:
# []

# %% [markdown]
# ---

# %%
import aspose.words as aw

doc = aw.Document("texte_2.pdf")
doc.save("texte_2.txt")

# %% [markdown]
# ---

# %%
import fitz  
# pip install PyMuPDF

def extract_text_from_pdf(file_path):
    pdf_document = fitz.open(file_path)
    text = ""
    for page_num in range(pdf_document.page_count):
        page = pdf_document.load_page(page_num)
        text += page.get_text()
    return text

pdf_path = 'texte_1.pdf'
text = extract_text_from_pdf(pdf_path)
text
# Out:
# ''

# %% [markdown]
# ---

# %%
from pdf2image import convert_from_path
import pytesseract

images = convert_from_path('texte_2.pdf')
print ("Nombre de pages: " + str(len(images)))
for i in range (len(images)):
    print ("Page N°" + str(i+1) + "\n")
    print(pytesseract.image_to_string(images[i]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pdf2image/pdf2image.py:581, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout, first_page, last_page)
#     580     env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 581 proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     583 try:
#
# File ~/anaconda3/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# ...
