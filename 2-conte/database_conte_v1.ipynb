# %% [markdown]
# <p style="color:#FFF; background:#951587; padding:12px; font-size:20px; font-style:italic; text-align:center">
# <span style="width:100%; display:inline-block; text-align:left">ABARKAN Suhaïla</span>
# <span style="font-size:48px; font-style:normal"><b>Conte de l'âne triste</b></span><br>
# <span style="width:49%; display:inline-block; text-align:left">06/06/2024 - 12/07/2024</span>
# <span style="width:49%; display:inline-block; text-align:right">CMI ISI</span></p>

# %% [markdown]
# ---
# <h2 style="padding:16px; color:#FFF; background:#951587">Imports nécessaires</h2>

# %%
# pip install xlrd pandas re os requests openpyxl Levenshtein (si ce n'est pas fait)
import pandas as pd
import re
import os
import requests
import Levenshtein as lv
from collections import Counter

# %% [markdown]
# ---
# <h2 style="padding:16px; color:#FFF; background:#951587">Création de la base de données sous un fichier .csv à l'aide de fichiers Excel</h2>

# %%
def list_files(directory):
    """Récupération de tous les fichiers excel (.xls et .xlsx) dans le dossier "directory"."""
    return [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith(('.xls', '.xlsx'))]

# %%
def extract_info(file):
    """Extraction du numéro INSEE et de l'identifiant du locuteur dans le nom des fichiers Excel."""
    match = re.match(r'PaRL_(\d{5})_(e\d{2})_Questionnaire_Conte', file)
    if match:
        return match.groups()
    return None, None  # dans le cas où les infos sont pas/mal renseignées

# %%
def filter_excel(file):
    """Filtrage des fichiers Excel pour récupérer les informations du conte et du locuteur."""
    df = pd.read_excel(file, sheet_name=0)
    # lignes du conte commençant par des numéros (1, 2, ..., 44)
    conte_df = df[df.iloc[:, 0].astype(str).str.match(r'^\d+.*')]
    # lignes contenant les infos du locuteur
    locuteur_df = df.iloc[-8:, 2].tolist()
    return conte_df, locuteur_df

# %%
def get_geo_info(code_insee):
    """Récupération des informations géographiques selon le code INSEE, via une api."""
    url = f'https://geo.api.gouv.fr/communes/{code_insee}?fields=nom,code,codesPostaux,surface,population,centre,contour,departement'
    response = requests.get(url)
    data = response.json()
    return {
        'ville': data['nom'],
        'departement': data['departement']['nom'],
        'x': data['centre']['coordinates'][0],
        'y': data['centre']['coordinates'][1]
    }

# %%
def split_text(text):
    """Séparation mot à mot d'une phrase."""
    # convertit tout le texte en minuscules, supprime les virgules et les apostrophes, et sépare les mots
    words = re.split(r"[^\w']+", text.lower().replace(',', '').replace("'", ' '))
    # supprime les mots vides et les espaces
    words = [word.strip() for word in words if word.strip()]
    return words

# %%
def create_csv(files, output_csv='bdd_conte_v1.csv'):
    """Création de fichier .csv sous 'bdd_conte_v1.csv' en remplissant avec les informations des fichier Excel."""
    # création des tableaux (vides pour l'instant)
    phrases = []
    traductions = []
    commentaires = []
    locuteur_infos = []

    for file in files:  # récupération des données correspondantes
        conte_df, locuteur_df = filter_excel(file)
        if not phrases:
            phrases = conte_df.iloc[:, 1].tolist()
        traductions.append(conte_df.iloc[:, 2].tolist())
        commentaires.append(conte_df.iloc[:, 3].tolist())
        locuteur_infos.append(locuteur_df)

    columns = ['code_INSEE', 'ville', 'departement', 'x', 'y', 'identifiant', 'age', 'lieu_de_naissance',
               'sexe', 'lieu_de_residence', 'parler_local', 'commune_apprentissage', 'profession', 'adresse_courriel']

    # on gère le cas où il y a le même mot dans une même phrase
    word_counts = {}
    for i, phrase in enumerate(phrases):
        words = split_text(phrase)
        columns.append(phrase)
        columns.append(f'commentaire_phrase_{i+1}')
        for word in words:
            col_name = f'{word}_MOT_phrase_{i+1}'
            if col_name in word_counts:  # si le mot apparait déjà
                col_name = f'{word}_MOT_phrase_{i+1}_bis'
            else:
                word_counts[col_name] = 1
            columns.append(col_name)

    df_output = pd.DataFrame(columns=columns)

    for x, file in enumerate(files):
        # remplissage des lignes de données
        code_insee, identifiant = extract_info(file.split('/')[-1])
        geo_info = get_geo_info(code_insee)
        locuteur_info = locuteur_infos[x]
        row = [code_insee, geo_info['ville'], geo_info['departement'], geo_info['x'], geo_info['y'],
               identifiant, locuteur_info[0], locuteur_info[1], locuteur_info[2], locuteur_info[3],
               locuteur_info[4], locuteur_info[5], locuteur_info[6], locuteur_info[7]]

        for i in range(len(phrases)):
            row.append(traductions[x][i])
            row.append(commentaires[x][i])
            phrase_words = split_text(phrases[i])
            traduction_words = split_text(traductions[x][i])

            for word_index, word in enumerate(phrase_words):
                # trouver les mots les plus proches en termes de position
                # 1er cas : len(traduction_words) = len(phrase_words)
                start = word_index
                end = word_index + 1
                # 2e cas :
                if len(traduction_words) < len(phrase_words):
                    start = max(0, word_index - 1 -
                                (len(phrase_words) - len(traduction_words)))
                    end = min(len(traduction_words), word_index + 2 +
                              (len(phrase_words) - len(traduction_words)))
                # 3e cas :
                elif len(traduction_words) > len(phrase_words):
                    start = max(0, word_index - 1 -
                                (len(traduction_words) - len(phrase_words)))
                    end = min(len(traduction_words), word_index + 2 +
                              (len(traduction_words) - len(phrase_words)))

                context_words = traduction_words[start:end]

                min_distance = float('inf')
                best_match = ''
                for trad_word in context_words:
                    distance = lv.distance(word, trad_word)
                    if distance < min_distance:
                        min_distance = distance
                        best_match = trad_word

                # ajoute le mot traduit trouvé ou laisse vide si aucun mot n'est trouvé
                row.append(f'{best_match}' if best_match else '')

                # idée : si une MEME traduction est donnée pour 2 mots dans la phrase,
                # alors on choisit la traduction qui a la plus petite distance de Levenshtein ?
                # pour n'utiliser qu'une traduction à la fois

        df_output.loc[x] = row

    df_output.to_csv(output_csv, index=False)
    return df_output

# %% [markdown]
# <h4 style="padding:16px; color:#FFF; background:#C180BA">Création du fichier .csv</h4>

# %%
directory = 'reponses'  # le dossier contenant tous les fichiers excel
files = list_files(directory)
df = create_csv(files)

# %% [markdown]
# ---
# <h2 style="padding:16px; color:#FFF; background:#951587">Tables de contingence et fréquences des types d'opérations</h2>

# %%
def get_operations(word1, word2):  # valable que pour deux traductions à la fois
    """Extraction des opérations entre deux mots en utilisant Levenshtein."""
    operations = lv.editops(word1, word2)
    details = []
    details.append(f"{word1} -> {word2}")
    contingency_table = {"insertions": 0,
                         "suppressions": 0, "substitutions": 0}
    if word1 == word2:
        details.append("Les mots sont identiques.")
    else:
        for op in operations:
            if op[0] == 'insert':
                contingency_table["insertions"] += 1
                details.append(
                    f"Insertion de '{word2[op[2]]}' à la position {op[1]}")
            elif op[0] == 'delete':
                contingency_table["suppressions"] += 1
                details.append(
                    f"Suppression de '{word1[op[1]]}' à la position {op[1]}")
            elif op[0] == 'replace':
                contingency_table["substitutions"] += 1
                details.append(
                    f"Substitution de '{word1[op[1]]}' par '{word2[op[2]]}' à la position {op[1]}")
    return contingency_table, details, operations


def create_contingency_table(df, word_col):
    """Création d'une table de contingence montrant les opérations entre paires de mots."""
    translations = df[word_col].dropna().values
    word1, word2 = translations[:2]
    contingency_table, details, operations = get_operations(word1, word2)
    contingency_df = pd.DataFrame([contingency_table])
    details_df = pd.DataFrame(details, columns=["Détails"])
    return contingency_df, details_df, operations, word1, word2


def most_common_operations(operation_count, operation_type, N=5):
    """Affichage des N opérations les plus fréquentes pour un type donné."""
    most_common = operation_count.most_common(N)
    if most_common:
        print(f"\n Les {operation_type}s les plus fréquentes :")
        for i, (operation, count) in enumerate(most_common):
            print(f"{i+1}. {operation}: {count}")
    else:
        print(f"\nAucune {operation_type} trouvée.")

# %% [markdown]
# <h4 style="padding:16px; color:#FFF; background:#C180BA">Affichage des tables de contingences</h4>

# %% [markdown]
# Indication : cliquer sur "scrollable element" ou "text editor" pour avoir le détail de toutes les tables.

# %%
# compteurs pour les opérations spécifiques
insertion_operations = Counter()
suppression_operations = Counter()
substitution_operations = Counter()

# affichage des tables de contigences, avec le détail des opérations effectuées par Levenshtein
for i in range(1, 45):  # on parcourt tous les mots de toutes les phrases
    word_columns = [
        col for col in df.columns if col.endswith(f'_MOT_phrase_{i}')]
    for word_col in word_columns:
        contingency_table, details_tables, operations, word1, word2 = create_contingency_table(
            df, word_col)
        if contingency_table is not None:
            for op in operations:
                if op[0] == 'insert':
                    insertion_operations[word2[op[2]]
                                         ] += contingency_table['insertions'][0]
                elif op[0] == 'delete':
                    suppression_operations[word1[op[1]]
                                           ] += contingency_table['suppressions'][0]
                elif op[0] == 'replace':
                    substitution_operations[(
                        word1[op[1]], word2[op[2]])] += contingency_table['substitutions'][0]

            print(f"\nTable de contingence pour le mot '{word_col}':")
            print(contingency_table)
            print(details_tables)
# Out:
# Table de contingence pour le mot 'c_MOT_phrase_1':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     o -> o
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'est_MOT_phrase_1':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                                    lé -> let
# 1             Insertion de 'e' à la position 1
# 2  Substitution de 'é' par 't' à la position 1
#
# Table de contingence pour le mot 'l_MOT_phrase_1':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     l -> l
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'histoire_MOT_phrase_1':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                          histoire -> istoere
# 1           Suppression de 'h' à la position 0
# 2  Substitution de 'i' par 'e' à la position 5
#
# Table de contingence pour le mot 'd_MOT_phrase_1':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     d -> d
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'un_MOT_phrase_1':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                                    une -> in
# 1  Substitution de 'u' par 'i' à la position 0
# 2           Suppression de 'e' à la position 2
#
# Table de contingence pour le mot 'âne_MOT_phrase_1':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                   âne -> ane
# 1  Substitution de 'â' par 'a' à la position 0
#
# Table de contingence pour le mot 'triste_MOT_phrase_1':
#    insertions  suppressions  substitutions
# 0           0             4              1
#                                        Détails
# 0                                 triste -> in
# 1           Suppression de 't' à la position 0
# 2           Suppression de 'r' à la position 1
# 3  Substitution de 's' par 'n' à la position 3
# 4           Suppression de 't' à la position 4
# 5           Suppression de 'e' à la position 5
#
# Table de contingence pour le mot 'pas_MOT_phrase_1':
#    insertions  suppressions  substitutions
# 0           0             1              0
#                               Détails
# 0                           pas -> pa
# 1  Suppression de 's' à la position 2
#
# Table de contingence pour le mot 'très_MOT_phrase_1':
#    insertions  suppressions  substitutions
# 0           0             1              2
#                                        Détails
# 0                                    bin -> pa
# 1  Substitution de 'b' par 'p' à la position 0
# 2  Substitution de 'i' par 'a' à la position 1
# 3           Suppression de 'n' à la position 2
#
# Table de contingence pour le mot 'grand_MOT_phrase_1':
#    insertions  suppressions  substitutions
# 0           0             1              3
#                                        Détails
# 0                                grand -> haùt
# 1  Substitution de 'g' par 'h' à la position 0
# 2           Suppression de 'r' à la position 1
# 3  Substitution de 'n' par 'ù' à la position 3
# 4  Substitution de 'd' par 't' à la position 4
#
# Table de contingence pour le mot 'ça_MOT_phrase_2':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     o -> o
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'faisait_MOT_phrase_2':
#    insertions  suppressions  substitutions
# 0           0             2              2
#                                        Détails
# 0                             faisait -> feset
# 1  Substitution de 'a' par 'e' à la position 1
# 2           Suppression de 'i' à la position 2
# 3  Substitution de 'a' par 'e' à la position 4
# 4           Suppression de 'i' à la position 5
#
# Table de contingence pour le mot 'très_MOT_phrase_2':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     o -> o
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'longtemps_MOT_phrase_2':
#    insertions  suppressions  substitutions
# 0           0             2              5
#                                        Détails
# 0                         longtemps -> moument
# 1  Substitution de 'l' par 'm' à la position 0
# 2  Substitution de 'n' par 'u' à la position 2
# 3  Substitution de 'g' par 'm' à la position 3
# 4           Suppression de 't' à la position 4
# 5  Substitution de 'm' par 'n' à la position 6
# 6  Substitution de 'p' par 't' à la position 7
# 7           Suppression de 's' à la position 8
#
# Table de contingence pour le mot 'qu_MOT_phrase_2':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                 que -> que
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'il_MOT_phrase_2':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     l -> l
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'avait_MOT_phrase_2':
#    insertions  suppressions  substitutions
# 0           0             1              3
#                                        Détails
# 0                                était -> avet
# 1  Substitution de 'é' par 'a' à la position 0
# 2  Substitution de 't' par 'v' à la position 1
# 3  Substitution de 'a' par 'e' à la position 2
# 4           Suppression de 'i' à la position 3
#
# Table de contingence pour le mot 'pas_MOT_phrase_2':
#    insertions  suppressions  substitutions
# 0           0             1              0
#                               Détails
# 0                           pas -> pa
# 1  Suppression de 's' à la position 2
#
# Table de contingence pour le mot 'quitté_MOT_phrase_2':
#    insertions  suppressions  substitutions
# 0           1             1              2
#                                        Détails
# 0                               était -> guité
# 1  Substitution de 'é' par 'g' à la position 0
# 2  Substitution de 't' par 'u' à la position 1
# 3           Suppression de 'a' à la position 2
# 4             Insertion de 'é' à la position 5
#
# Table de contingence pour le mot 'son_MOT_phrase_2':
#    insertions  suppressions  substitutions
# 0           0             0              3
#                                        Détails
# 0                                   pas -> sun
# 1  Substitution de 'p' par 's' à la position 0
# 2  Substitution de 'a' par 'u' à la position 1
# 3  Substitution de 's' par 'n' à la position 2
#
# Table de contingence pour le mot 'village_MOT_phrase_2':
#    insertions  suppressions  substitutions
# 0           5             0              1
#                                        Détails
# 0                                de -> village
# 1             Insertion de 'v' à la position 0
# 2             Insertion de 'i' à la position 0
# 3             Insertion de 'l' à la position 0
# 4             Insertion de 'l' à la position 0
# 5             Insertion de 'a' à la position 0
# 6  Substitution de 'd' par 'g' à la position 0
#
# Table de contingence pour le mot 'il_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   le -> le
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'ne_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   le -> le
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'pouvait_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           0             2              1
#                                        Détails
# 0                             pouvait -> pouvé
# 1  Substitution de 'a' par 'é' à la position 4
# 2           Suppression de 'i' à la position 5
# 3           Suppression de 't' à la position 6
#
# Table de contingence pour le mot 'aller_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           0             0              2
#                                        Détails
# 0                                 alla -> alae
# 1  Substitution de 'l' par 'a' à la position 2
# 2  Substitution de 'a' par 'e' à la position 3
#
# Table de contingence pour le mot 'presque_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           4             0              1
#                                        Détails
# 0                                 le -> queque
# 1             Insertion de 'q' à la position 0
# 2             Insertion de 'u' à la position 0
# 3             Insertion de 'e' à la position 0
# 4             Insertion de 'q' à la position 0
# 5  Substitution de 'l' par 'u' à la position 0
#
# Table de contingence pour le mot 'nulle_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           0             1              2
#                                        Détails
# 0                                nulle -> alae
# 1  Substitution de 'n' par 'a' à la position 0
# 2           Suppression de 'u' à la position 1
# 3  Substitution de 'l' par 'a' à la position 3
#
# Table de contingence pour le mot 'part_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0               part -> part
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'parce_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0               part -> part
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'qu_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           1             0              0
#                             Détails
# 0                           l -> le
# 1  Insertion de 'e' à la position 1
#
# Table de contingence pour le mot 'on_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           1             0              0
#                             Détails
# 0                           n -> in
# 1  Insertion de 'i' à la position 0
#
# Table de contingence pour le mot 'l_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     l -> l
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'avait_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           1             0              4
#                                        Détails
# 0                              était -> avians
# 1             Insertion de 'a' à la position 0
# 2  Substitution de 'é' par 'v' à la position 0
# 3  Substitution de 't' par 'i' à la position 1
# 4  Substitution de 'i' par 'n' à la position 3
# 5  Substitution de 't' par 's' à la position 4
#
# Table de contingence pour le mot 'attaché_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           0             1              0
#                               Détails
# 0                   attaché -> ataché
# 1  Suppression de 't' à la position 2
#
# Table de contingence pour le mot 'à_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     à -> à
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'un_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                     un -> in
# 1  Substitution de 'u' par 'i' à la position 0
#
# Table de contingence pour le mot 'piquet_MOT_phrase_3':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0           piquet -> piquet
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'il_MOT_phrase_4':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     l -> l
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'n_MOT_phrase_4':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     l -> l
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'aimait_MOT_phrase_4':
#    insertions  suppressions  substitutions
# 0           0             2              1
#                                        Détails
# 0                               aimait -> aimé
# 1  Substitution de 'a' par 'é' à la position 3
# 2           Suppression de 'i' à la position 4
# 3           Suppression de 't' à la position 5
#
# Table de contingence pour le mot 'que_MOT_phrase_4':
#    insertions  suppressions  substitutions
# 0           2             0              0
#                             Détails
# 0                      que -> reque
# 1  Insertion de 'r' à la position 0
# 2  Insertion de 'e' à la position 0
#
# Table de contingence pour le mot 'lui_MOT_phrase_4':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   li -> li
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'même_MOT_phrase_4':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                                    que -> le
# 1  Substitution de 'q' par 'l' à la position 0
# 2           Suppression de 'u' à la position 1
#
# Table de contingence pour le mot 'et_MOT_phrase_4':
#    insertions  suppressions  substitutions
# 0           0             0              2
#                                        Détails
# 0                                     li -> et
# 1  Substitution de 'l' par 'e' à la position 0
# 2  Substitution de 'i' par 't' à la position 1
#
# Table de contingence pour le mot 'ne_MOT_phrase_4':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   le -> le
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'disait_MOT_phrase_4':
#    insertions  suppressions  substitutions
# 0           0             2              3
#                                        Détails
# 0                             causait -> diset
# 1  Substitution de 'c' par 'd' à la position 0
# 2  Substitution de 'a' par 'i' à la position 1
# 3           Suppression de 'u' à la position 2
# 4  Substitution de 'a' par 'e' à la position 4
# 5           Suppression de 'i' à la position 5
#
# Table de contingence pour le mot 'rien_MOT_phrase_4':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                                    le -> ren
# 1  Substitution de 'l' par 'r' à la position 0
# 2             Insertion de 'n' à la position 2
#
# Table de contingence pour le mot 'à_MOT_phrase_4':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                       à -> a
# 1  Substitution de 'à' par 'a' à la position 0
#
# Table de contingence pour le mot 'personne_MOT_phrase_4':
#    insertions  suppressions  substitutions
# 0           0             2              0
#                               Détails
# 0                peursoune -> prsoune
# 1  Suppression de 'e' à la position 1
# 2  Suppression de 'u' à la position 2
#
# Table de contingence pour le mot 'la_MOT_phrase_5':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   la -> la
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'semaine_MOT_phrase_5':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0         semaine -> semaine
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'dernière_MOT_phrase_5':
#    insertions  suppressions  substitutions
# 0           0             2              0
#                               Détails
# 0                    derrère -> drère
# 1  Suppression de 'e' à la position 1
# 2  Suppression de 'r' à la position 2
#
# Table de contingence pour le mot 'une_MOT_phrase_5':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                   une -> ine
# 1  Substitution de 'u' par 'i' à la position 0
#
# Table de contingence pour le mot 'fillette_MOT_phrase_5':
#    insertions  suppressions  substitutions
# 0           0             5              2
#                                        Détails
# 0                              drolesse -> ine
# 1  Substitution de 'd' par 'i' à la position 0
# 2  Substitution de 'r' par 'n' à la position 1
# 3           Suppression de 'o' à la position 2
# 4           Suppression de 'l' à la position 3
# 5           Suppression de 'e' à la position 4
# 6           Suppression de 's' à la position 5
# 7           Suppression de 's' à la position 6
#
# Table de contingence pour le mot 's_MOT_phrase_5':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   sé -> sé
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'est_MOT_phrase_5':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   sé -> sé
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'retrouvée_MOT_phrase_5':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                          trouvée -> trouvaie
# 1             Insertion de 'a' à la position 5
# 2  Substitution de 'é' par 'i' à la position 5
#
# Table de contingence pour le mot 'face_MOT_phrase_5':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   sé -> sé
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'à_MOT_phrase_5':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   li -> li
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'lui_MOT_phrase_5':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   li -> li
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'quand_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                               quand -> quant
# 1  Substitution de 'd' par 't' à la position 4
#
# Table de contingence pour le mot 'il_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     l -> l
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'l_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     l -> l
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'a_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     a -> a
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'vue_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                                    que -> vu
# 1  Substitution de 'q' par 'v' à la position 0
# 2           Suppression de 'e' à la position 2
#
# Table de contingence pour le mot 'cette_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           3             0              2
#                                        Détails
# 0                                que -> chiète
# 1             Insertion de 'c' à la position 0
# 2             Insertion de 'h' à la position 0
# 3             Insertion de 'i' à la position 0
# 4  Substitution de 'q' par 'è' à la position 0
# 5  Substitution de 'u' par 't' à la position 1
#
# Table de contingence pour le mot 'petite_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           1             0              4
#                                        Détails
# 0                              avait -> chiète
# 1  Substitution de 'a' par 'c' à la position 0
# 2  Substitution de 'v' par 'h' à la position 1
# 3  Substitution de 'a' par 'i' à la position 2
# 4  Substitution de 'i' par 'è' à la position 3
# 5             Insertion de 'e' à la position 5
#
# Table de contingence pour le mot 'âne_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                   âne -> ane
# 1  Substitution de 'â' par 'a' à la position 0
#
# Table de contingence pour le mot 'sursauté_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           3             0              3
#                                        Détails
# 0                            avait -> resautae
# 1             Insertion de 'r' à la position 0
# 2  Substitution de 'a' par 'e' à la position 0
# 3  Substitution de 'v' par 's' à la position 1
# 4  Substitution de 'i' par 'u' à la position 3
# 5             Insertion de 'a' à la position 5
# 6             Insertion de 'e' à la position 5
#
# Table de contingence pour le mot 'n_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                       l -> a
# 1  Substitution de 'l' par 'a' à la position 0
#
# Table de contingence pour le mot 'avait_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                                avait -> avet
# 1  Substitution de 'a' par 'e' à la position 2
# 2           Suppression de 'i' à la position 3
#
# Table de contingence pour le mot 'rien_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                   rin -> ren
# 1  Substitution de 'i' par 'e' à la position 1
#
# Table de contingence pour le mot 'entendu_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0         entendu -> entendu
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'du_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           0             1              2
#                                        Détails
# 0                                    pou -> ni
# 1  Substitution de 'p' par 'n' à la position 0
# 2  Substitution de 'o' par 'i' à la position 1
# 3           Suppression de 'u' à la position 2
#
# Table de contingence pour le mot 'tout_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           2             0              1
#                                        Détails
# 0                                     l -> ren
# 1             Insertion de 'r' à la position 0
# 2             Insertion de 'e' à la position 0
# 3  Substitution de 'l' par 'n' à la position 0
#
# Table de contingence pour le mot 'ni_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                                    rin -> ni
# 1  Substitution de 'r' par 'n' à la position 0
# 2           Suppression de 'n' à la position 2
#
# Table de contingence pour le mot 'personne_MOT_phrase_6':
#    insertions  suppressions  substitutions
# 0           4             0              1
#                                        Détails
# 0                               rin -> prsoune
# 1             Insertion de 'p' à la position 0
# 2             Insertion de 's' à la position 1
# 3             Insertion de 'o' à la position 1
# 4  Substitution de 'i' par 'u' à la position 1
# 5             Insertion de 'e' à la position 3
#
# Table de contingence pour le mot 'il_MOT_phrase_7':
#    insertions  suppressions  substitutions
# 0           1             0              0
#                             Détails
# 0                           l -> le
# 1  Insertion de 'e' à la position 1
#
# Table de contingence pour le mot 'lui_MOT_phrase_7':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                     le -> li
# 1  Substitution de 'e' par 'i' à la position 1
#
# Table de contingence pour le mot 'a_MOT_phrase_7':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     a -> a
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'tourné_MOT_phrase_7':
#    insertions  suppressions  substitutions
# 0           0             1              0
#                               Détails
# 0                     tourné -> torné
# 1  Suppression de 'u' à la position 2
#
# Table de contingence pour le mot 'le_MOT_phrase_7':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     l -> l
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'dos_MOT_phrase_7':
#    insertions  suppressions  substitutions
# 0           4             0              1
#                                        Détails
# 0                                 de -> echine
# 1             Insertion de 'e' à la position 0
# 2             Insertion de 'c' à la position 0
# 3             Insertion de 'h' à la position 0
# 4             Insertion de 'i' à la position 0
# 5  Substitution de 'd' par 'n' à la position 0
#
# Table de contingence pour le mot 'hier_MOT_phrase_8':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0               hier -> hier
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'elle_MOT_phrase_8':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                       a -> l
# 1  Substitution de 'a' par 'l' à la position 0
#
# Table de contingence pour le mot 'a_MOT_phrase_8':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                       l -> a
# 1  Substitution de 'l' par 'a' à la position 0
#
# Table de contingence pour le mot 'réessayé_MOT_phrase_8':
#    insertions  suppressions  substitutions
# 0           8             0              0
#                             Détails
# 0                    a -> rasseillé
# 1  Insertion de 'r' à la position 0
# 2  Insertion de 's' à la position 1
# 3  Insertion de 's' à la position 1
# 4  Insertion de 'e' à la position 1
# 5  Insertion de 'i' à la position 1
# 6  Insertion de 'l' à la position 1
# 7  Insertion de 'l' à la position 1
# 8  Insertion de 'é' à la position 1
#
# Table de contingence pour le mot 'd_MOT_phrase_8':
#    insertions  suppressions  substitutions
# 0           0             7              1
#                                        Détails
# 0                                rééssayé -> d
# 1  Substitution de 'r' par 'd' à la position 0
# 2           Suppression de 'é' à la position 1
# 3           Suppression de 'é' à la position 2
# 4           Suppression de 's' à la position 3
# 5           Suppression de 's' à la position 4
# 6           Suppression de 'a' à la position 5
# 7           Suppression de 'y' à la position 6
# 8           Suppression de 'é' à la position 7
#
# Table de contingence pour le mot 'attirer_MOT_phrase_8':
#    insertions  suppressions  substitutions
# 0           3             0              2
#                                        Détails
# 0                                  de -> atiré
# 1             Insertion de 'a' à la position 0
# 2             Insertion de 't' à la position 0
# 3             Insertion de 'i' à la position 0
# 4  Substitution de 'd' par 'r' à la position 0
# 5  Substitution de 'e' par 'é' à la position 1
#
# Table de contingence pour le mot 'son_MOT_phrase_8':
#    insertions  suppressions  substitutions
# 0           2             0              1
#                                        Détails
# 0                                     l -> sun
# 1             Insertion de 's' à la position 0
# 2             Insertion de 'u' à la position 0
# 3  Substitution de 'l' par 'n' à la position 0
#
# Table de contingence pour le mot 'attention_MOT_phrase_8':
#    insertions  suppressions  substitutions
# 0           0             1              7
#                                        Détails
# 0                        intéressa -> atenciun
# 1  Substitution de 'i' par 'a' à la position 0
# 2           Suppression de 'n' à la position 1
# 3  Substitution de 'é' par 'e' à la position 3
# 4  Substitution de 'r' par 'n' à la position 4
# 5  Substitution de 'e' par 'c' à la position 5
# 6  Substitution de 's' par 'i' à la position 6
# 7  Substitution de 's' par 'u' à la position 7
# 8  Substitution de 'a' par 'n' à la position 8
#
# Table de contingence pour le mot 'elle_MOT_phrase_9':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                                      a -> et
# 1             Insertion de 'e' à la position 0
# 2  Substitution de 'a' par 't' à la position 0
#
# Table de contingence pour le mot 'n_MOT_phrase_9':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     a -> a
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'y_MOT_phrase_9':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                       y -> a
# 1  Substitution de 'y' par 'a' à la position 0
#
# Table de contingence pour le mot 'est_MOT_phrase_9':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                                      a -> et
# 1             Insertion de 'e' à la position 0
# 2  Substitution de 'a' par 't' à la position 0
#
# Table de contingence pour le mot 'toujours_MOT_phrase_9':
#    insertions  suppressions  substitutions
# 0           2             0              3
#                                        Détails
# 0                                 pas -> trjou
# 1             Insertion de 't' à la position 0
# 2             Insertion de 'r' à la position 0
# 3  Substitution de 'p' par 'j' à la position 0
# 4  Substitution de 'a' par 'o' à la position 1
# 5  Substitution de 's' par 'u' à la position 2
#
# Table de contingence pour le mot 'pas_MOT_phrase_9':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                 pas -> pas
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'arrivée_MOT_phrase_9':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                          arrivée -> arrivaîe
# 1             Insertion de 'a' à la position 5
# 2  Substitution de 'é' par 'î' à la position 5
#
# Table de contingence pour le mot 'ce_MOT_phrase_10':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                       à -> a
# 1  Substitution de 'à' par 'a' à la position 0
#
# Table de contingence pour le mot 'matin_MOT_phrase_10':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0             matin -> matin
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'la_MOT_phrase_10':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   la -> la
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'fillette_MOT_phrase_10':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                        drolesse -> draulesse
# 1             Insertion de 'a' à la position 2
# 2  Substitution de 'o' par 'u' à la position 2
#
# Table de contingence pour le mot 'est_MOT_phrase_10':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                                      et -> é
# 1  Substitution de 'e' par 'é' à la position 0
# 2           Suppression de 't' à la position 1
#
# Table de contingence pour le mot 'revenue_MOT_phrase_10':
#    insertions  suppressions  substitutions
# 0           2             1              0
#                               Détails
# 0                 revenue -> revenjhu
# 1    Insertion de 'j' à la position 5
# 2    Insertion de 'h' à la position 5
# 3  Suppression de 'e' à la position 6
#
# Table de contingence pour le mot 'franchement_MOT_phrase_11':
#    insertions  suppressions  substitutions
# 0           4             0              1
#                                        Détails
# 0                                   y -> laren
# 1             Insertion de 'l' à la position 0
# 2             Insertion de 'a' à la position 0
# 3             Insertion de 'r' à la position 0
# 4             Insertion de 'e' à la position 0
# 5  Substitution de 'y' par 'n' à la position 0
#
# Table de contingence pour le mot 'rien_MOT_phrase_11':
#    insertions  suppressions  substitutions
# 0           1             1              3
#                                        Détails
# 0                               avait -> laren
# 1             Insertion de 'l' à la position 0
# 2  Substitution de 'v' par 'r' à la position 1
# 3  Substitution de 'a' par 'e' à la position 2
# 4  Substitution de 'i' par 'n' à la position 3
# 5           Suppression de 't' à la position 4
#
# Table de contingence pour le mot 'ne_MOT_phrase_11':
#    insertions  suppressions  substitutions
# 0           0             1              2
#                                        Détails
# 0                                    rin -> la
# 1  Substitution de 'r' par 'l' à la position 0
# 2  Substitution de 'i' par 'a' à la position 1
# 3           Suppression de 'n' à la position 2
#
# Table de contingence pour le mot 'la_MOT_phrase_11':
#    insertions  suppressions  substitutions
# 0           0             2              2
#                                        Détails
# 0                                   pour -> la
# 1  Substitution de 'p' par 'l' à la position 0
# 2  Substitution de 'o' par 'a' à la position 1
# 3           Suppression de 'u' à la position 2
# 4           Suppression de 'r' à la position 3
#
# Table de contingence pour le mot 'décourageait_MOT_phrase_11':
#    insertions  suppressions  substitutions
# 0           9             0              1
#                                         Détails
# 0                             la -> décourajhai
# 1              Insertion de 'd' à la position 0
# 2              Insertion de 'é' à la position 0
# 3              Insertion de 'c' à la position 0
# 4              Insertion de 'o' à la position 0
# 5              Insertion de 'u' à la position 0
# 6   Substitution de 'l' par 'r' à la position 0
# 7              Insertion de 'j' à la position 2
# 8              Insertion de 'h' à la position 2
# 9              Insertion de 'a' à la position 2
# 10             Insertion de 'i' à la position 2
#
# Table de contingence pour le mot 'elle_MOT_phrase_11':
#    insertions  suppressions  substitutions
# 0           0             8              1
#                                        Détails
# 0                             découragea -> la
# 1  Substitution de 'd' par 'l' à la position 0
# 2           Suppression de 'é' à la position 1
# 3           Suppression de 'c' à la position 2
# 4           Suppression de 'o' à la position 3
# 5           Suppression de 'u' à la position 4
# 6           Suppression de 'r' à la position 5
# 7           Suppression de 'a' à la position 6
# 8           Suppression de 'g' à la position 7
# 9           Suppression de 'e' à la position 8
#
# Table de contingence pour le mot 'elle_MOT_phrase_12':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     a -> a
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'lui_MOT_phrase_12':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                       a -> i
# 1  Substitution de 'a' par 'i' à la position 0
#
# Table de contingence pour le mot 'a_MOT_phrase_12':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     a -> a
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'enfin_MOT_phrase_12':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0             enfin -> enfin
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'parlé_MOT_phrase_12':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                              causé -> causae
# 1             Insertion de 'a' à la position 4
# 2  Substitution de 'é' par 'e' à la position 4
#
# Table de contingence pour le mot 'à_MOT_phrase_12':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                       y -> a
# 1  Substitution de 'y' par 'a' à la position 0
#
# Table de contingence pour le mot 'l_MOT_phrase_12':
#    insertions  suppressions  substitutions
# 0           4             0              1
#                                        Détails
# 0                                   a -> chiet
# 1             Insertion de 'c' à la position 0
# 2             Insertion de 'h' à la position 0
# 3             Insertion de 'i' à la position 0
# 4             Insertion de 'e' à la position 0
# 5  Substitution de 'a' par 't' à la position 0
#
# Table de contingence pour le mot 'âne_MOT_phrase_12':
#    insertions  suppressions  substitutions
# 0           0             2              2
#                                        Détails
# 0                                 enfin -> ane
# 1  Substitution de 'e' par 'a' à la position 0
# 2  Substitution de 'f' par 'e' à la position 2
# 3           Suppression de 'i' à la position 3
# 4           Suppression de 'n' à la position 4
#
# Table de contingence pour le mot 'la_MOT_phrase_13':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   la -> la
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'fillette_MOT_phrase_13':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                        drolesse -> draulesse
# 1             Insertion de 'a' à la position 2
# 2  Substitution de 'o' par 'u' à la position 2
#
# Table de contingence pour le mot 'est_MOT_phrase_13':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                                      as -> t
# 1  Substitution de 'a' par 't' à la position 0
# 2           Suppression de 's' à la position 1
#
# Table de contingence pour le mot 'ce_MOT_phrase_13':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   la -> la
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'qu_MOT_phrase_13':
#    insertions  suppressions  substitutions
# 0           0             0              2
#                                        Détails
# 0                                     tu -> la
# 1  Substitution de 't' par 'l' à la position 0
# 2  Substitution de 'u' par 'a' à la position 1
#
# Table de contingence pour le mot 'on_MOT_phrase_13':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                                      as -> t
# 1  Substitution de 'a' par 't' à la position 0
# 2           Suppression de 's' à la position 1
#
# Table de contingence pour le mot 't_MOT_phrase_13':
#    insertions  suppressions  substitutions
# 0           0             1              0
#                               Détails
# 0                             tu -> t
# 1  Suppression de 'u' à la position 1
#
# Table de contingence pour le mot 'a_MOT_phrase_13':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   ta -> ta
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'déjà_MOT_phrase_13':
#    insertions  suppressions  substitutions
# 0           1             0              2
#                                        Détails
# 0                                  été -> déja
# 1             Insertion de 'd' à la position 0
# 2  Substitution de 't' par 'j' à la position 1
# 3  Substitution de 'é' par 'a' à la position 2
#
# Table de contingence pour le mot 'détaché_MOT_phrase_13':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0         détaché -> détaché
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'toi_MOT_phrase_13':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   ta -> ta
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'l_MOT_phrase_14':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     l -> l
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'âne_MOT_phrase_14':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                   âne -> ane
# 1  Substitution de 'â' par 'a' à la position 0
#
# Table de contingence pour le mot 'non_MOT_phrase_14':
#    insertions  suppressions  substitutions
# 0           0             0              2
#                                        Détails
# 0                                   nan -> num
# 1  Substitution de 'a' par 'u' à la position 1
# 2  Substitution de 'n' par 'm' à la position 2
#
# Table de contingence pour le mot 'la_MOT_phrase_15':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   la -> la
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'fillette_MOT_phrase_15':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                        drolesse -> draulesse
# 1             Insertion de 'a' à la position 2
# 2  Substitution de 'o' par 'u' à la position 2
#
# Table de contingence pour le mot 'et_MOT_phrase_15':
#    insertions  suppressions  substitutions
# 0           0             0              2
#                                        Détails
# 0                                     la -> et
# 1  Substitution de 'l' par 'e' à la position 0
# 2  Substitution de 'a' par 't' à la position 1
#
# Table de contingence pour le mot 'tu_MOT_phrase_15':
#    insertions  suppressions  substitutions
# 0           0             1              0
#                               Détails
# 0                             tu -> t
# 1  Suppression de 'u' à la position 1
#
# Table de contingence pour le mot 'n_MOT_phrase_15':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                                      as -> t
# 1  Substitution de 'a' par 't' à la position 0
# 2           Suppression de 's' à la position 1
#
# Table de contingence pour le mot 'as_MOT_phrase_15':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   as -> as
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'jamais_MOT_phrase_15':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                              jhamé -> jhamae
# 1             Insertion de 'a' à la position 4
# 2  Substitution de 'é' par 'e' à la position 4
#
# Table de contingence pour le mot 'été_MOT_phrase_15':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                 été -> été
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'libre_MOT_phrase_15':
#    insertions  suppressions  substitutions
# 0           0             2              3
#                                        Détails
# 0                                 libre -> été
# 1  Substitution de 'l' par 'é' à la position 0
# 2  Substitution de 'i' par 't' à la position 1
# 3  Substitution de 'b' par 'é' à la position 2
# 4           Suppression de 'r' à la position 3
# 5           Suppression de 'e' à la position 4
#
# Table de contingence pour le mot 'l_MOT_phrase_16':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                     l -> l
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'âne_MOT_phrase_16':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                   âne -> ane
# 1  Substitution de 'â' par 'a' à la position 0
#
# Table de contingence pour le mot 'je_MOT_phrase_16':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                     me -> le
# 1  Substitution de 'm' par 'l' à la position 0
#
# Table de contingence pour le mot 'me_MOT_phrase_16':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                     me -> le
# 1  Substitution de 'm' par 'l' à la position 0
#
# Table de contingence pour le mot 'souviens_MOT_phrase_16':
#    insertions  suppressions  substitutions
# 0           0             1              2
#                                        Détails
# 0                                    que -> si
# 1  Substitution de 'q' par 's' à la position 0
# 2  Substitution de 'u' par 'i' à la position 1
# 3           Suppression de 'e' à la position 2
#
# Table de contingence pour le mot 'que_MOT_phrase_16':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                 que -> que
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'si_MOT_phrase_16':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   si -> si
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'avant_MOT_phrase_16':
#    insertions  suppressions  substitutions
# 0           1             0              0
#                             Détails
# 0                     vant -> avant
# 1  Insertion de 'a' à la position 0
#
# Table de contingence pour le mot 'qu_MOT_phrase_16':
#    insertions  suppressions  substitutions
# 0           1             0              2
#                                        Détails
# ...
# 0           0             1              1
#                                        Détails
# 0                            heureux -> eureus
# 1           Suppression de 'h' à la position 0
# 2  Substitution de 'x' par 's' à la position 6
#
# Table de contingence pour le mot 'sans_MOT_phrase_40':
#    insertions  suppressions  substitutions
# 0           0             2              1
#                                        Détails
# 0                                   sans -> si
# 1  Substitution de 'a' par 'i' à la position 1
# 2           Suppression de 'n' à la position 2
# 3           Suppression de 's' à la position 3
#
# Table de contingence pour le mot 'être_MOT_phrase_40':
#    insertions  suppressions  substitutions
# 0           0             1              0
#                               Détails
# 0                           éte -> ét
# 1  Suppression de 'e' à la position 2
#
# Table de contingence pour le mot 'libre_MOT_phrase_40':
#    insertions  suppressions  substitutions
# 0           0             3              1
#                                        Détails
# 0                                  libre -> si
# 1  Substitution de 'l' par 's' à la position 0
# 2           Suppression de 'b' à la position 2
# 3           Suppression de 'r' à la position 3
# 4           Suppression de 'e' à la position 4
#
# Table de contingence pour le mot 'du_MOT_phrase_40':
#    insertions  suppressions  substitutions
# 0           0             2              1
#                                        Détails
# 0                                     éte -> d
# 1  Substitution de 'é' par 'd' à la position 0
# 2           Suppression de 't' à la position 1
# 3           Suppression de 'e' à la position 2
#
# Table de contingence pour le mot 'tout_MOT_phrase_40':
#    insertions  suppressions  substitutions
# 0           0             1              0
#                               Détails
# 0                           éte -> ét
# 1  Suppression de 'e' à la position 2
#
# Table de contingence pour le mot 'allez_MOT_phrase_41':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0             allez -> allez
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'je_MOT_phrase_41':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                                      te -> i
# 1  Substitution de 't' par 'i' à la position 0
# 2           Suppression de 'e' à la position 1
#
# Table de contingence pour le mot 'te_MOT_phrase_41':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   te -> te
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'détacherai_MOT_phrase_41':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                      détacheré -> détacherai
# 1             Insertion de 'a' à la position 8
# 2  Substitution de 'é' par 'i' à la position 8
#
# Table de contingence pour le mot 'ce_MOT_phrase_41':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                                      te -> d
# 1  Substitution de 't' par 'd' à la position 0
# 2           Suppression de 'e' à la position 1
#
# Table de contingence pour le mot 'soir_MOT_phrase_41':
#    insertions  suppressions  substitutions
# 0           0             1              2
#                                        Détails
# 0                                  pour -> ser
# 1  Substitution de 'p' par 's' à la position 0
# 2  Substitution de 'o' par 'e' à la position 1
# 3           Suppression de 'u' à la position 2
#
# Table de contingence pour le mot 'pour_MOT_phrase_41':
#    insertions  suppressions  substitutions
# 0           0             2              0
#                               Détails
# 0                          pour -> pr
# 1  Suppression de 'o' à la position 1
# 2  Suppression de 'u' à la position 2
#
# Table de contingence pour le mot 'que_MOT_phrase_41':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                 que -> que
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'tu_MOT_phrase_41':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                     tu -> te
# 1  Substitution de 'u' par 'e' à la position 1
#
# Table de contingence pour le mot 'retrouves_MOT_phrase_41':
#    insertions  suppressions  substitutions
# 0           2             0              2
#                                        Détails
# 0                                 que -> sejhe
# 1             Insertion de 's' à la position 0
# 2             Insertion de 'e' à la position 0
# 3  Substitution de 'q' par 'j' à la position 0
# 4  Substitution de 'u' par 'h' à la position 1
#
# Table de contingence pour le mot 'la_MOT_phrase_41':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                                      tu -> d
# 1  Substitution de 't' par 'd' à la position 0
# 2           Suppression de 'u' à la position 1
#
# Table de contingence pour le mot 'liberté_MOT_phrase_41':
#    insertions  suppressions  substitutions
# 0           0             0              4
#                                        Détails
# 0                               libre -> épave
# 1  Substitution de 'l' par 'é' à la position 0
# 2  Substitution de 'i' par 'p' à la position 1
# 3  Substitution de 'b' par 'a' à la position 2
# 4  Substitution de 'r' par 'v' à la position 3
#
# Table de contingence pour le mot 'et_MOT_phrase_42':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   et -> et
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'n_MOT_phrase_42':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                                      y -> et
# 1             Insertion de 'e' à la position 0
# 2  Substitution de 'y' par 't' à la position 0
#
# Table de contingence pour le mot 'oublie_MOT_phrase_42':
#    insertions  suppressions  substitutions
# 0           5             0              1
#                                        Détails
# 0                                pi -> oubllie
# 1             Insertion de 'o' à la position 0
# 2             Insertion de 'u' à la position 0
# 3             Insertion de 'b' à la position 0
# 4             Insertion de 'l' à la position 0
# 5  Substitution de 'p' par 'l' à la position 0
# 6             Insertion de 'e' à la position 2
#
# Table de contingence pour le mot 'pas_MOT_phrase_42':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                     pi -> pa
# 1  Substitution de 'i' par 'a' à la position 1
#
# Table de contingence pour le mot 'la_MOT_phrase_42':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   la -> la
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'solitude_MOT_phrase_42':
#    insertions  suppressions  substitutions
# 0           1             1              3
#                                        Détails
# 0                         solitude -> souletai
# 1             Insertion de 'u' à la position 2
# 2  Substitution de 'i' par 'e' à la position 3
# 3  Substitution de 'u' par 'a' à la position 5
# 4  Substitution de 'd' par 'i' à la position 6
# 5           Suppression de 'e' à la position 7
#
# Table de contingence pour le mot 'peut_MOT_phrase_42':
#    insertions  suppressions  substitutions
# 0           0             2              1
#                                        Détails
# 0                                   peut -> pé
# 1  Substitution de 'e' par 'é' à la position 1
# 2           Suppression de 'u' à la position 2
# 3           Suppression de 't' à la position 3
#
# Table de contingence pour le mot 'durer_MOT_phrase_42':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                                dura -> durer
# 1             Insertion de 'e' à la position 3
# 2  Substitution de 'a' par 'r' à la position 3
#
# Table de contingence pour le mot 'longtemps_MOT_phrase_42':
#    insertions  suppressions  substitutions
# 0           0             2              5
#                                        Détails
# 0                         longtemps -> moument
# 1  Substitution de 'l' par 'm' à la position 0
# 2  Substitution de 'n' par 'u' à la position 2
# 3  Substitution de 'g' par 'm' à la position 3
# 4           Suppression de 't' à la position 4
# 5  Substitution de 'm' par 'n' à la position 6
# 6  Substitution de 'p' par 't' à la position 7
# 7           Suppression de 's' à la position 8
#
# Table de contingence pour le mot 'mais_MOT_phrase_42':
#    insertions  suppressions  substitutions
# 0           0             1              2
#                                        Détails
# 0                                    pas -> in
# 1  Substitution de 'p' par 'i' à la position 0
# 2  Substitution de 'a' par 'n' à la position 1
# 3           Suppression de 's' à la position 2
#
# Table de contingence pour le mot 'vie_MOT_phrase_42':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                 vie -> vie
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'non_MOT_phrase_42':
#    insertions  suppressions  substitutions
# 0           1             0              2
#                                        Détails
# 0                                    la -> num
# 1             Insertion de 'n' à la position 0
# 2  Substitution de 'l' par 'u' à la position 0
# 3  Substitution de 'a' par 'm' à la position 1
#
# Table de contingence pour le mot 'â_MOT_phrase_43':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                       y -> a
# 1  Substitution de 'y' par 'a' à la position 0
#
# Table de contingence pour le mot 'je_MOT_phrase_43':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                                      sé -> a
# 1  Substitution de 's' par 'a' à la position 0
# 2           Suppression de 'é' à la position 1
#
# Table de contingence pour le mot 'ne_MOT_phrase_43':
#    insertions  suppressions  substitutions
# 0           0             2              0
#                               Détails
# 0                            pas -> a
# 1  Suppression de 'p' à la position 0
# 2  Suppression de 's' à la position 2
#
# Table de contingence pour le mot 'suis_MOT_phrase_43':
#    insertions  suppressions  substitutions
# 0           0             2              1
#                                        Détails
# 0                                     cor -> i
# 1  Substitution de 'c' par 'i' à la position 0
# 2           Suppression de 'o' à la position 1
# 3           Suppression de 'r' à la position 2
#
# Table de contingence pour le mot 'pas_MOT_phrase_43':
#    insertions  suppressions  substitutions
# 0           0             0              2
#                                        Détails
# 0                                   pra -> pas
# 1  Substitution de 'r' par 'a' à la position 1
# 2  Substitution de 'a' par 's' à la position 2
#
# Table de contingence pour le mot 'encore_MOT_phrase_43':
#    insertions  suppressions  substitutions
# 0           2             0              1
#                                        Détails
# 0                                     à -> cor
# 1             Insertion de 'c' à la position 0
# 2             Insertion de 'o' à la position 0
# 3  Substitution de 'à' par 'r' à la position 0
#
# Table de contingence pour le mot 'prêt_MOT_phrase_43':
#    insertions  suppressions  substitutions
# 0           3             0              1
#                                        Détails
# 0                                    m -> pret
# 1             Insertion de 'p' à la position 0
# 2             Insertion de 'r' à la position 0
# 3             Insertion de 'e' à la position 0
# 4  Substitution de 'm' par 't' à la position 0
#
# Table de contingence pour le mot 'à_MOT_phrase_43':
#    insertions  suppressions  substitutions
# 0           0             1              1
#                                        Détails
# 0                                      en -> à
# 1  Substitution de 'e' par 'à' à la position 0
# 2           Suppression de 'n' à la position 1
#
# Table de contingence pour le mot 'partir_MOT_phrase_43':
#    insertions  suppressions  substitutions
# 0           0             3              1
#                                        Détails
# 0                                    alla -> à
# 1  Substitution de 'a' par 'à' à la position 0
# 2           Suppression de 'l' à la position 1
# 3           Suppression de 'l' à la position 2
# 4           Suppression de 'a' à la position 3
#
# Table de contingence pour le mot 'même_MOT_phrase_44':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                               maème -> maeme
# 1  Substitution de 'è' par 'e' à la position 2
#
# Table de contingence pour le mot 'si_MOT_phrase_44':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   si -> si
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'je_MOT_phrase_44':
#    insertions  suppressions  substitutions
# 0           1             0              1
#                                        Détails
# 0                                      j -> si
# 1             Insertion de 's' à la position 0
# 2  Substitution de 'j' par 'i' à la position 0
#
# Table de contingence pour le mot 'ne_MOT_phrase_44':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                   si -> si
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'l_MOT_phrase_44':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                       j -> l
# 1  Substitution de 'j' par 'l' à la position 0
#
# Table de contingence pour le mot 'aime_MOT_phrase_44':
#    insertions  suppressions  substitutions
# 0           0             0              1
#                                        Détails
# 0                                 aéme -> aime
# 1  Substitution de 'é' par 'i' à la position 1
#
# Table de contingence pour le mot 'pas_MOT_phrase_44':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                 pas -> pas
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'beaucoup_MOT_phrase_44':
#    insertions  suppressions  substitutions
# 0           0             0              0
#                      Détails
# 0                 pas -> pas
# 1  Les mots sont identiques.
#
# Table de contingence pour le mot 'ce_MOT_phrase_44':
#    insertions  suppressions  substitutions
# 0           2             0              1
#                                        Détails
# 0                                 cho -> tchau
# 1             Insertion de 't' à la position 0
# 2             Insertion de 'a' à la position 2
# 3  Substitution de 'o' par 'u' à la position 2
#
# Table de contingence pour le mot 'village_MOT_phrase_44':
#    insertions  suppressions  substitutions
# 0           0             2              0
#                               Détails
# 0                  villaghe -> vilage
# 1  Suppression de 'l' à la position 3
# 2  Suppression de 'h' à la position 6

# %% [markdown]
# <h4 style="padding:16px; color:#FFF; background:#C180BA">Calcul des fréquences des types d'opérations et des opérations par type</h4>

# %%
total_operations = len(insertion_operations) + len(suppression_operations) + len(substitution_operations)

insertions_frequency = len(insertion_operations) / total_operations
suppressions_frequency = len(suppression_operations) / total_operations
substitutions_frequency = len(substitution_operations) / total_operations

print(f"Fréquence des types d'opérations :")
print(f"Insertions : {insertions_frequency:.2%}")
print(f"Suppressions : {suppressions_frequency:.2%}")
print(f"Substitutions : {substitutions_frequency:.2%}")
# Out:
# Fréquence des types d'opérations :
# Insertions : 9.09%
# Suppressions : 9.09%
# Substitutions : 81.82%

# %%
most_common_operations(insertion_operations, "insertion")
most_common_operations(suppression_operations, "suppression")
most_common_operations(substitution_operations, "substitution")
# Out:
#  Les insertions les plus fréquentes :
# 1. e: 100
# 2. a: 83
# 3. i: 80
# 4. l: 65
# 5. r: 51
#
#  Les suppressions les plus fréquentes :
# 1. s: 94
# 2. e: 69
# 3. u: 67
# 4. t: 50
# 5. o: 49
#
#  Les substitutions les plus fréquentes :
# 1. ('a', 'e'): 24
# 2. ('a', 'i'): 24
# 3. ('a', 'u'): 21
# 4. ('i', 'e'): 20
# 5. ('s', 'u'): 16
